# %% [markdown]
# # Imports

# %%
import csv
import numpy as np

# %% [markdown]
# # Input

# %%
tensor = np.load("input/tensor.npy")
tensor.shape
# Out:
# (2, 5, 10, 4)

# %%
kernel = np.load("input/kernel.npy")
kernel.shape
# Out:
# (3, 3, 4, 3)

# %%
bias = np.load("input/bias.npy")
bias.shape
# Out:
# (3,)

# %%
with open("input/task.csv", newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    params = dict(zip(next(reader), map(int, next(reader))))
stride = params['stride']
stride
# Out:
# 1

# %% [markdown]
# # Process

# %% [markdown]
# ## Define the output tensor

# %%
kH, kW = kernel.shape[0], kernel.shape[1]
N = tensor.shape[0]
H = (tensor.shape[1] - kH) // stride + 1
W = (tensor.shape[2] - kW) // stride + 1
C = kernel.shape[3]
conv = np.zeros((N, H, W, C))
conv.shape
# Out:
# (2, 3, 8, 3)

# %% [markdown]
# ## Apply convolution

# %%
for i in range(H):
    for j in range(W):
        conv[:, i, j, :] = np.tensordot(
            tensor[:, i*stride:i*stride+kH, j*stride:j*stride+kW, :], 
            kernel, axes=([1, 2, 3], [0, 1, 2]))

# %%
conv
# Out:
# array([[[[ -5.15172633,   2.36936664,   6.11307183],
#          [ -7.91001299, -12.3488115 ,  -4.44041922],
#          [  1.91904602,   6.06905743,   1.33058873],
#          [  3.97600343,  -8.78595781,  -4.86135358],
#          [ -9.4740406 ,   6.88915893,   2.75064975],
#          [ -2.23668064,   0.42469886,   2.23198336],
#          [ -2.71410696,   9.87916742,  -7.16767207],
#          [ -3.04129197,   9.92691491,  -1.1791704 ]],
#
#         [[  4.88719169,  -2.31829998,  13.79423603],
#          [-11.67798802,   2.04695416,   0.28590376],
#          [ 12.36864441,   5.54778102,   2.83350733],
#          [ -6.86389662,   0.57835827,   6.7184039 ],
#          [ -1.25044898,   5.10015488,  -0.64352469],
#          [  4.9130674 ,  -1.90735763,   5.41332992],
#          [ -9.47115573,   6.82668294,   4.47640388],
#          [ -0.43112406,   6.45322185,   5.42609729]],
#
#         [[ -2.36235692,  -0.20743586,   0.6624685 ],
#          [  1.70381199,  -3.49485298,  -6.93848039],
#          [  2.96656326,   3.73041512,   1.4266605 ],
#          [  5.85168063,   0.44269109,   2.10266876],
#          [  2.40684893,   2.59205642,   4.39633246],
#          [ -7.22020985,   4.9620363 ,   0.6018251 ],
#          [  5.98417828,   8.32210966,  10.22174773],
#          [ -5.24164569,   2.50206254,   8.21293975]]],
#
#
#        [[[  5.12928706,  -6.38928544,  -7.5617314 ],
#          [ 10.63687026,   0.49845491,   4.25650944],
#          [ -1.96326506,   8.92864924,  -0.25614622],
#          [  3.12371946,  14.91972998,   1.87275646],
#          [ -5.73035043,   0.81537276,   6.96756523],
#          [ -3.94412256,  -2.87485953,   1.26744575],
#          [  3.81447904,  -5.92289272,  -4.31228301],
#          [  3.12085118, -12.15683107, -10.22354293]],
#
#         [[  8.50800016,  -2.43915469,  -9.35138589],
#          [  1.49962308,   2.01049756,  -5.86521155],
#          [ -8.98137132,   4.26810729,   7.17496368],
#          [  1.94648745,   3.06973879,   9.12566163],
#          [ -9.39280804,  -4.98264065,  -1.33378748],
#          [  3.17222675,  12.31902289,   3.15845648],
#          [  1.53940818,   0.51370215,  -4.91389339],
#          [ -8.91445571,  -7.24875481,  -6.32378727]],
#
#         [[  4.9527977 ,   3.58750718,  -1.85089246],
#          [  1.96727957,  -2.3454899 ,   7.21906197],
#          [ -6.40979268,  -0.35748165,  -7.61304175],
#          [  8.35081956,   8.61534505,   8.90157756],
#          [ -2.91958756,   2.38475245,   0.16144209],
#          [  9.46843397,   4.16613322,   9.64298936],
#          [ -1.693319  ,  11.61294719,   4.83108429],
#          [ -7.56933555,   4.48422707,  -7.8719629 ]]]])

# %% [markdown]
# ## Apply bias

# %%
conv += bias[None, None, None, :].repeat(W, 2).repeat(H, 1).repeat(N, 0)

# %%
conv
# Out:
# array([[[[-3.27122184e+00,  1.86702325e+00,  7.06887704e+00],
#          [-6.02950850e+00, -1.28511549e+01, -3.48461401e+00],
#          [ 3.79955051e+00,  5.56671404e+00,  2.28639394e+00],
#          [ 5.85650792e+00, -9.28830120e+00, -3.90554837e+00],
#          [-7.59353611e+00,  6.38681554e+00,  3.70645496e+00],
#          [-3.56176153e-01, -7.76445325e-02,  3.18778857e+00],
#          [-8.33602474e-01,  9.37682403e+00, -6.21186686e+00],
#          [-1.16078748e+00,  9.42457152e+00, -2.23365193e-01]],
#
#         [[ 6.76769618e+00, -2.82064337e+00,  1.47500412e+01],
#          [-9.79748354e+00,  1.54461077e+00,  1.24170897e+00],
#          [ 1.42491489e+01,  5.04543763e+00,  3.78931254e+00],
#          [-4.98339214e+00,  7.60148830e-02,  7.67420911e+00],
#          [ 6.30055507e-01,  4.59781149e+00,  3.12280523e-01],
#          [ 6.79357188e+00, -2.40970102e+00,  6.36913513e+00],
#          [-7.59065125e+00,  6.32433955e+00,  5.43220909e+00],
#          [ 1.44938043e+00,  5.95087846e+00,  6.38190250e+00]],
#
#         [[-4.81852434e-01, -7.09779251e-01,  1.61827370e+00],
#          [ 3.58431648e+00, -3.99719637e+00, -5.98267518e+00],
#          [ 4.84706775e+00,  3.22807173e+00,  2.38246571e+00],
#          [ 7.73218511e+00, -5.96523007e-02,  3.05847397e+00],
#          [ 4.28735342e+00,  2.08971303e+00,  5.35213767e+00],
#          [-5.33970536e+00,  4.45969291e+00,  1.55763031e+00],
#          [ 7.86468277e+00,  7.81976627e+00,  1.11775529e+01],
#          [-3.36114120e+00,  1.99971916e+00,  9.16874496e+00]]],
#
#
#        [[[ 7.00979155e+00, -6.89162883e+00, -6.60592619e+00],
#          [ 1.25173747e+01, -3.88848372e-03,  5.21231465e+00],
#          [-8.27605727e-02,  8.42630585e+00,  6.99658989e-01],
#          [ 5.00422395e+00,  1.44173866e+01,  2.82856167e+00],
#          [-3.84984594e+00,  3.13029371e-01,  7.92337044e+00],
#          [-2.06361807e+00, -3.37720292e+00,  2.22325096e+00],
#          [ 5.69498353e+00, -6.42523611e+00, -3.35647780e+00],
#          [ 5.00135566e+00, -1.26591745e+01, -9.26773772e+00]],
#
#         [[ 1.03885046e+01, -2.94149808e+00, -8.39558068e+00],
#          [ 3.38012756e+00,  1.50815417e+00, -4.90940634e+00],
#          [-7.10086684e+00,  3.76576390e+00,  8.13076889e+00],
#          [ 3.82699194e+00,  2.56739540e+00,  1.00814668e+01],
#          [-7.51230355e+00, -5.48498404e+00, -3.77982267e-01],
#          [ 5.05273124e+00,  1.18166795e+01,  4.11426169e+00],
#          [ 3.41991267e+00,  1.13587626e-02, -3.95808818e+00],
#          [-7.03395122e+00, -7.75109820e+00, -5.36798206e+00]],
#
#         [[ 6.83330219e+00,  3.08516379e+00, -8.95087246e-01],
#          [ 3.84778405e+00, -2.84783329e+00,  8.17486717e+00],
#          [-4.52928820e+00, -8.59825038e-01, -6.65723654e+00],
#          [ 1.02313240e+01,  8.11300166e+00,  9.85738277e+00],
#          [-1.03908308e+00,  1.88240906e+00,  1.11724730e+00],
#          [ 1.13489385e+01,  3.66378983e+00,  1.05987946e+01],
#          [ 1.87185487e-01,  1.11106038e+01,  5.78688950e+00],
#          [-5.68883107e+00,  3.98188368e+00, -6.91615769e+00]]]])

# %% [markdown]
# ## Output

# %%
np.save("output/seminar03_conv.npy", conv, allow_pickle=False)
